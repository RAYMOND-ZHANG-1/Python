# %%
# Import libarires
import pandas as pd
import numpy as np
import os

# %%
# Set acess path
path=r'C:\Users\SuperHome\Documents\Instacart Basket Analysis\02 Data'

# %%
df_orders=pd.read_csv(os.path.join(path,'Original Data','orders.csv'),index_col=False)

# %%
## Data Wrangling on Orders

# %%
# Checking orders head
df_orders.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# Dropping unusful column 'eval_set'
df_ord=df_orders.drop(columns=['eval_set'])

# %%
# Check new head
df_ord.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# Finding na values from all coulmns
df_ord.isnull().any() # True indicates na values
# Out:
# order_id                  False
# user_id                   False
# order_number              False
# order_dow                 False
# order_hour_of_day         False
# days_since_prior_order     True
# dtype: bool

# %%
# Finding na values from the rows
df_ord[df_ord.isnull().values==True] # There are 206209 na values
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0         2539329        1             1          2                  8
# 11        2168274        2             1          2                 11
# 26        1374495        3             1          1                 14
# 39        3343014        4             1          6                 11
# 45        2717275        5             1          3                 12
# ...           ...      ...           ...        ...                ...
# 3420930    969311   206205             1          4                 12
# 3420934   3189322   206206             1          3                 18
# 3421002   2166133   206207             1          6                 19
# 3421019   2227043   206208             1          1                 15
# 3421069   3154581   206209             1          3                 11
#
#          days_since_prior_order
# 0                           NaN
# 11                          NaN
# ...

# %%
# Changing Data type

# %%
#1. Checking summerize data
df_ord.describe()
# Out:
#            order_id       user_id  order_number   day_of_week  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710542e+06  1.029782e+05  1.715486e+01  2.776219e+00
# std    9.875817e+05  5.953372e+04  1.773316e+01  2.046829e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    8.552715e+05  5.139400e+04  5.000000e+00  1.000000e+00
# 50%    1.710542e+06  1.026890e+05  1.100000e+01  3.000000e+00
# 75%    2.565812e+06  1.543850e+05  2.300000e+01  5.000000e+00
# max    3.421083e+06  2.062090e+05  1.000000e+02  6.000000e+00
#
#        order_hour_of_day  days_since_prior_order
# count       3.421083e+06            3.214874e+06
# mean        1.345202e+01            1.111484e+01
# std         4.226088e+00            9.206737e+00
# min         0.000000e+00            0.000000e+00
# 25%         1.000000e+01            4.000000e+00
# 50%         1.300000e+01            7.000000e+00
# 75%         1.600000e+01            1.500000e+01
# ...

# %%
#2. order_id and user_id don't need to appear in the above table

# %%
#3. changing data type on order_id
df_ord['order_id']=df_ord['order_id'].astype('str')

# %%
# Question 2. changing another dataframe user_id
df_ord['user_id']=df_ord['user_id'].astype('str')

# %%
#5 new summerizeing data 
df_ord.describe()
# Out:
#        order_number   day_of_week  order_hour_of_day  days_since_prior_order
# count  3.421083e+06  3.421083e+06       3.421083e+06            3.214874e+06
# mean   1.715486e+01  2.776219e+00       1.345202e+01            1.111484e+01
# std    1.773316e+01  2.046829e+00       4.226088e+00            9.206737e+00
# min    1.000000e+00  0.000000e+00       0.000000e+00            0.000000e+00
# 25%    5.000000e+00  1.000000e+00       1.000000e+01            4.000000e+00
# 50%    1.100000e+01  3.000000e+00       1.300000e+01            7.000000e+00
# 75%    2.300000e+01  5.000000e+00       1.600000e+01            1.500000e+01
# max    1.000000e+02  6.000000e+00       2.300000e+01            3.000000e+01

# %%
# Question 3 Renaming column 'order_dow'
df_ord.rename(columns={'order_dow':'day_of_week'},inplace=True)

# %%
# Checking new columns
df_ord.columns
# Out:
# Index(['order_id', 'user_id', 'order_number', 'day_of_week',
#        'order_hour_of_day', 'days_since_prior_order'],
#       dtype='object')

# %%
# Question 4 Find the frequency of the corresponding variable
df_ord['order_hour_of_day'].value_counts()
# Out:
# 10    288418
# 11    284728
# 15    283639
# 14    283042
# 13    277999
# 12    272841
# 16    272553
# 9     257812
# 17    228795
# 18    182912
# 8     178201
# 19    140569
# 20    104292
# 7      91868
# 21     78109
# 22     61468
# 23     40043
# 6      30529
# 0      22758
# 1      12398
# 5       9569
# 2       7539
# 4       5527
# 3       5474
# Name: order_hour_of_day, dtype: int64

# %%
df_ord['order_hour_of_day'].describe()
# Out:
# count    3.421083e+06
# mean     1.345202e+01
# std      4.226088e+00
# min      0.000000e+00
# 25%      1.000000e+01
# 50%      1.300000e+01
# 75%      1.600000e+01
# max      2.300000e+01
# Name: order_hour_of_day, dtype: float64

# %%
The business hours across the whole day from 12am to 23pm, the busiest time is
10am and followed by 11am and then 15pm. The most busiest order period is from 10am to 15pm.

# %%
# The busiest time
df_ord['order_hour_of_day'].mode()
# Out:
# 0    10
# Name: order_hour_of_day, dtype: int64

# %%
Data Wrangling on departments

# %%
# import departments dataframe
df_departments=pd.read_csv(os.path.join(path,'Original Data','departments.csv'),index_col=False)

# %%
# Checking departments head
df_departments.head()
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9  ...            12      13         14  \
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %%
# Changing columns to rows
df_dep=df_departments.T

# %%
# Checking new head
df_dep.head()
# Out:
#                         0
# department_id  department
# 1                  frozen
# 2                   other
# 3                  bakery
# 4                 produce

# %%
# Setup column index
df_dep.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
# Create new header
new_header=df_dep.iloc[0]

# %%
# Delete first row with 0,resetup row's order
df_dep_new=df_dep[1:]

# %%
# Insert new header
df_dep_new.columns=new_header

# %%
df_dep_new
# Out:
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
# Creating data dictinary
data_dict=df_dep_new.to_dict('index')

# %%
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
# Importing products dataframe
df_products=pd.read_csv(os.path.join(path,'Original Data','products.csv'),index_col=False)

# %%
# Checking products head
df_products.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
# Question 5 Determine the meaning behind a value of 4 in the "department_id" column
print(data_dict.get('4'))
# Out:
# {'department': 'produce'}

# %%
# Question 6 Create a subset containing breakfast items sales
df_breakfast=df_products.loc[df_products['department_id']==14]

# %%
df_breakfast
# Out:
#        product_id                                       product_name  \
# 27             28                                  Wheat Chex Cereal
# 33             34                                                NaN
# 67             68                            Pancake Mix, Buttermilk
# 89             90                                       Smorz Cereal
# 210           211   Gluten Free Organic Cereal Coconut Maple Vanilla
# ...           ...                                                ...
# 49330       49326                            Cereal Variety Fun Pack
# 49395       49391            Light and Fluffy Buttermilk Pancake Mix
# 49547       49543                          Chocolate Cheerios Cereal
# 49637       49633               Shake 'N Pour Buttermilk Pancake Mix
# 49667       49663  Ultra Protein Power Crunch Peanut Butter N' Ho...
#
#        aisle_id  department_id  prices
# 27          121             14    10.1
# 33          121             14    12.2
# ...

# %%
# Question 7 
df_dinner_party=df_products.loc[df_products['department_id'].isin([5,7,12,20])]

# %%
df_dinner_party
# Out:
#        product_id                                    product_name  aisle_id  \
# 2               3            Robust Golden Unsweetened Oolong Tea        94
# 6               7                  Pure Coconut Water With Orange        98
# 9              10  Sparkling Orange Juice & Prickly Pear Beverage       115
# 10             11                               Peach Mango Juice        31
# 16             17                               Rendered Duck Fat        35
# ...           ...                                             ...       ...
# 49676       49672                          Cafe Mocha K-Cup Packs        26
# 49679       49675             Cinnamon Dolce Keurig Brewed K Cups        26
# 49680       49676                          Ultra Red Energy Drink        64
# 49686       49682                              California Limeade        98
# 49688       49684       Vodka, Triple Distilled, Twist of Vanilla       124
#
#        department_id  prices
# ...

# %%
Question 8 How many rows does the last dataframe you created have?
There are 7650 rows in the dinner_party dataframe.

# %%
# Question 9 User_id 1 all information
df_ord.head(20)
# Out:
#    order_id user_id  order_number  day_of_week  order_hour_of_day  \
# 0   2539329       1             1            2                  8
# 1   2398795       1             2            3                  7
# 2    473747       1             3            3                 12
# 3   2254736       1             4            4                  7
# 4    431534       1             5            4                 15
# 5   3367565       1             6            2                  7
# 6    550135       1             7            1                  9
# 7   3108588       1             8            1                 14
# 8   2295261       1             9            1                 16
# 9   2550362       1            10            4                  8
# 10  1187899       1            11            4                  8
# 11  2168274       2             1            2                 11
# 12  1501582       2             2            5                 10
# ...

# %%
# From above table wen can see user_id 1 contians 11 rows
df_ord.head(11)
# Out:
#    order_id user_id  order_number  day_of_week  order_hour_of_day  \
# 0   2539329       1             1            2                  8
# 1   2398795       1             2            3                  7
# 2    473747       1             3            3                 12
# 3   2254736       1             4            4                  7
# 4    431534       1             5            4                 15
# 5   3367565       1             6            2                  7
# 6    550135       1             7            1                  9
# 7   3108588       1             8            1                 14
# 8   2295261       1             9            1                 16
# 9   2550362       1            10            4                  8
# 10  1187899       1            11            4                  8
#
#     days_since_prior_order
# 0                      NaN
# 1                     15.0
# 2                     21.0
# 3                     29.0
# 4                     28.0
# ...

# %%
 Question 10
1.This customer made 11 total of orders, and
2.This customer never order on Friday but most on Thursday
3.This customer likes ordering in the morning between 7am to 8am.

# %%
# Question 11 Export your df_ords dataframe as “orders_wrangled.csv
df_ord.to_csv(os.path.join(path,'Prepared Data','orders_wrangled.csv'))

# %%
# Question 12 Export the df_dep_t_new dataframe as “departments_wrangled.csv” 
df_dep_new.to_csv(os.path.join(path,'Prepared Data','departments_wrangled.csv'))
